# %%
import numpy as np
import pandas as pd

# %%
columns = [
    'Subject',
    'Measuring station',
    'repetition no.',
    'Neck girth',
    'Back neck point to waist',
    'Upper arm girth R',
    'Back neck point to wrist R',
    'Across back shoulder width',
    'Bust girth',
    'Waist girth',
    'Hip girth',
    'Thigh girth R',
    'Total crotch length',
    'Inside leg height',
]

# %%
measures_data = pd.read_csv("data/MOVE4D/body_measurements.csv", sep=';')
measures_data = measures_data[columns]
station_list=np.append(measures_data["Measuring station"].unique(), "Meu")

# %%
for column in columns:
    if column != 'Measuring station' and column != 'Subject':
        filtered = measures_data[column] > 2000
        measures_data[column].loc[filtered] /= 1000

# %%
extra_data = pd.read_csv('data/MOVE4D/basic_informations.csv', sep=';')

# %%
treated_data = pd.merge(measures_data, extra_data, on='Subject')
treated_data = treated_data.drop(['Pantone', 'BMI (kg/m^2)'], axis=1)

# %%
treated_data.to_pickle("data/cleaned_measures.zip")

# %%
pd.read_pickle("data/cleaned_measures.zip")
# Out:
#         Subject  Measuring station  repetition no.  Neck girth  \
# 0     IEEEP1_05  Expert measurer 1               1       335.0
# 1     IEEEP1_05  Expert measurer 1               2       345.0
# 2     IEEEP1_05  Expert measurer 2               1       340.0
# 3     IEEEP1_05  Expert measurer 2               2       330.0
# 4     IEEEP1_05  Expert measurer 3               1       335.0
# ...         ...                ...             ...         ...
# 2006  IEEEP2_72             3DLOOK               2       381.2
# 2007  IEEEP2_72  Expert measurer 1               1       355.0
# 2008  IEEEP2_72  Expert measurer 1               2       360.0
# 2009  IEEEP2_72  Expert measurer 5               1       355.0
# 2010  IEEEP2_72  Expert measurer 5               2       353.0
#
#       Back neck point to waist  Upper arm girth R  Back neck point to wrist R  \
# 0                        375.0              315.0                       790.0
# 1                        370.0              310.0                       760.0
# 2                        405.0              312.5                       755.0
# 3                        410.0              310.0                       745.0
# 4                        395.0              310.0                       735.0
# ...                        ...                ...                         ...
# 2006                     467.7              293.9                       836.6
# 2007                     435.0              305.0                       850.0
# 2008                     450.0              315.0                       840.0
# 2009                     427.0              321.0                       795.0
# 2010                     433.0              320.0                       798.0
#
#       Across back shoulder width  Bust girth  Waist girth  Hip girth  \
# 0                          430.0       920.0        800.0     1065.0
# 1                          405.0       925.0        810.0      965.0
# 2                          395.0       955.0        847.5     1050.0
# 3                          402.5       960.0        865.0     1065.0
# 4                          395.0       955.0        835.0     1045.0
# ...                          ...         ...          ...        ...
# 2006                       428.2       915.4        798.2      968.0
# 2007                       435.0       930.0        825.0      985.0
# 2008                       435.0       930.0        860.0      985.0
# 2009                       434.0       936.0        854.0      969.0
# 2010                       440.0       935.0        875.0      970.0
#
#       Thigh girth R  Total crotch length  Inside leg height  Phase      Sex  \
# 0             675.0                810.0              730.0      1  female
# 1             655.0                790.0              725.0      1  female
# 2             670.0                735.0              715.0      1  female
# 3             675.0                735.0              715.0      1  female
# 4             650.0                760.0              710.0      1  female
# ...             ...                  ...                ...    ...      ...
# 2006          580.1                767.0              823.5      2     male
# 2007          565.0                785.0              835.0      2     male
# 2008          570.0                730.0              835.0      2     male
# 2009          579.0                755.0              845.0      2     male
# 2010          570.0                750.0              854.0      2     male
#
#       Age (years)  Weight (kg)  Height (m)
# 0              25         69.4       1.641
# 1              25         69.4       1.641
# 2              25         69.4       1.641
# 3              25         69.4       1.641
# 4              25         69.4       1.641
# ...           ...          ...         ...
# 2006           25         70.7       1.775
# 2007           25         70.7       1.775
# 2008           25         70.7       1.775
# 2009           25         70.7       1.775
# 2010           25         70.7       1.775
#
# [2011 rows x 19 columns]
