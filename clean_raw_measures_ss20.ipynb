# %%
import numpy as np
import pandas as pd

# %%
columns = [
    'Subject',
    'Measuring station',
    'repetition no.',
    'Neck girth',
    'Back neck point to waist',
    'Upper arm girth R',
    'Back neck point to wrist R',
    'Across back shoulder width',
    'Bust girth',
    'Waist girth',
    'Hip girth',
    'Thigh girth R',
    'Total crotch length',
    'Inside leg height',
]

# %%
measures_data = pd.read_csv("data/SS20/body_measurements.csv", sep=';')
measures_data = measures_data[columns]
station_list=np.append(measures_data["Measuring station"].unique(), "Meu")

# %%
for column in columns:
    if column != 'Measuring station' and column != 'Subject':
        filtered = measures_data[column] > 2000
        measures_data[column].loc[filtered] /= 1000

# %%
extra_data = pd.read_csv('data/SS20/basic_informations.csv', sep=';')

# %%
treated_data = pd.merge(measures_data, extra_data, on='Subject')
treated_data = treated_data.drop(['Pantone', 'BMI (kg/m^2)'], axis=1)
treated_data = treated_data[treated_data['Phase'] == 1]

# %%
treated_data.to_pickle("data/ss20_cleaned_measures.zip")

# %%
pd.read_pickle("data/ss20_cleaned_measures.zip")
# Out:
#        Subject  Measuring station  repetition no.  Neck girth  \
# 0    IEEEP1_05  Expert measurer 1               1     335.000
# 1    IEEEP1_05  Expert measurer 1               2     345.000
# 2    IEEEP1_05  Expert measurer 2               1     340.000
# 3    IEEEP1_05  Expert measurer 2               2     330.000
# 4    IEEEP1_05  Expert measurer 3               1     335.000
# ..         ...                ...             ...         ...
# 715  IEEEP1_90              Vitus               2     338.000
# 716  IEEEP1_90               SS20               1     341.376
# 717  IEEEP1_90               SS20               2     348.996
# 718  IEEEP1_85              Vitus               1     323.000
# 719  IEEEP1_85              Vitus               2     319.000
#
#      Back neck point to waist  Upper arm girth R  Back neck point to wrist R  \
# 0                     375.000            315.000                     790.000
# 1                     370.000            310.000                     760.000
# 2                     405.000            312.500                     755.000
# 3                     410.000            310.000                     745.000
# 4                     395.000            310.000                     735.000
# ..                        ...                ...                         ...
# 715                   384.000            273.000                     787.000
# 716                   412.369            299.974                     762.254
# 717                   416.687            302.260                     765.175
# 718                   367.000            275.000                     695.000
# 719                   364.000            269.000                     696.000
#
#      Across back shoulder width  Bust girth  Waist girth  Hip girth  \
# 0                       430.000     920.000      800.000   1065.000
# 1                       405.000     925.000      810.000    965.000
# 2                       395.000     955.000      847.500   1050.000
# 3                       402.500     960.000      865.000   1065.000
# 4                       395.000     955.000      835.000   1045.000
# ..                          ...         ...          ...        ...
# 715                     408.000    1029.000      808.000    968.000
# 716                     367.157    1013.460      855.599    965.708
# 717                     359.918    1012.317      854.964    978.916
# 718                     402.000     919.000      762.000    967.000
# 719                     404.000     917.000      763.000    963.000
#
#      Thigh girth R  Total crotch length  Inside leg height  Phase      Sex  \
# 0          675.000              810.000            730.000      1  female
# 1          655.000              790.000            725.000      1  female
# 2          670.000              735.000            715.000      1  female
# 3          675.000              735.000            715.000      1  female
# 4          650.000              760.000            710.000      1  female
# ..             ...                  ...                ...    ...      ...
# 715        556.000              793.000            732.000      1  female
# 716        569.976              720.725            728.853      1  female
# 717        580.517              728.091            729.488      1  female
# 718        558.000              751.000            728.000      1  female
# 719        566.000              754.000            736.000      1  female
#
#      Age (years)  Weight (kg)  Height (m)
# 0             25         69.4       1.641
# 1             25         69.4       1.641
# 2             25         69.4       1.641
# 3             25         69.4       1.641
# 4             25         69.4       1.641
# ..           ...          ...         ...
# 715           38         65.8       1.630
# 716           38         65.8       1.630
# 717           38         65.8       1.630
# 718           16         58.3       1.580
# 719           16         58.3       1.580
#
# [720 rows x 19 columns]
