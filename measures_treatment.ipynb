# %%
import numpy as np
import pandas as pd
import pingouin as pg
import matplotlib.pyplot as plt

# %% [markdown]
# # DATA TREATMENT

# %%
columns = [
    'Subject',
    'Measuring station',
    'repetition no.',
    'Neck girth',
    'Back neck point to waist',
    'Upper arm girth R',
    'Back neck point to wrist R',
    'Across back shoulder width',
    'Bust girth',
    'Waist girth',
    'Hip girth',
    'Thigh girth R',
    'Total crotch length',
    'Inside leg height',
]

# %%
measures_data = pd.read_csv("data/body_measurements.csv", sep=';')
measures_data = measures_data[columns]
measures_list = ['Neck girth', 'Back neck point to waist', 'Upper arm girth R', 'Back neck point to wrist R', 'Across back shoulder width', 'Bust girth', 'Waist girth', 'Hip girth', 'Thigh girth R', 'Total crotch length', 'Inside leg height']
station_list=measures_data["Measuring station"].unique()

# %%
for column in columns:
    if column != 'Measuring station' and column != 'Subject':
        filtered = measures_data[column] > 2000
        measures_data[column].loc[filtered] /= 1000

# %%
extra_data = pd.read_csv('data/basic_informations.csv', sep=';')

# %%
treated_data = pd.merge(measures_data, extra_data, on='Subject')
treated_data = treated_data.drop(['Pantone', 'BMI (kg/m^2)'], axis=1)

# %%
treated_data[treated_data['Sex'] == 'male'].to_pickle('data/male_measures.zip')
treated_data[treated_data['Sex'] == 'female'].to_pickle('data/female_measures.zip')

# %%
outliers = []
subjects_list = treated_data['Subject'].unique()
for subject in subjects_list:
    for measure in measures_list:
        temp_data = treated_data[treated_data["Subject"] == subject][["Measuring station", 'Subject','repetition no.', measure]].copy()
        temp_data[measure]
        q1 = temp_data[measure].quantile(0.25)
        q3 = temp_data[measure].quantile(0.75)
        iqr = q3 - q1 #Interquartile range
        fence_low = q1 - (1.5*iqr)
        fence_high = q3 + (1.5*iqr)

        filter = (temp_data[measure] < fence_low) | (temp_data[measure] > fence_high)
        outliers.extend(temp_data[filter].index)
outliers = pd.Series(outliers)

# %%
outliers = []
subjects_list = treated_data['Subject'].unique()
for subject in subjects_list:
    for measure in measures_list:
        temp_data = treated_data[treated_data["Subject"] == subject][["Measuring station", 'Subject','repetition no.', measure]].copy()
        zscore = (temp_data[measure] - temp_data[measure].mean()) / (temp_data[measure].std())
        filter = abs(zscore) > 3
        outliers.extend(temp_data[filter].index)
outliers = pd.Series(outliers)
outliers = treated_data.loc[outliers]['Subject'].unique()

# %%
#treated_data = treated_data.drop(outliers)
treated_data = treated_data[~treated_data["Subject"].isin(outliers)]

# %% [markdown]
# # CALC ICC

# %%
their_icc = pd.read_csv('data/their_icc.csv', sep=',', header=0)
their_icc = their_icc.drop(['Measuring station'], axis=1)
their_icc.index = ['Expert measurer 1', 'Expert measurer 2', 'Expert measurer 3', 'Expert measurer 4', 'Expert measurer 5', 'SS20', 'Vitus', 'PortalMX', 'MOVE4D', 'SS@Home', '3DLOOK', 'eM+', '3Davatarbody']
their_icc.columns = measures_list
their_icc.sort_index()


all_measures = []
for station in station_list:
    measures_of_station = []
    for measure in measures_list:
        a = treated_data[treated_data['Measuring station'] == station].reset_index()
        icc = pg.intraclass_corr(data=a, targets='Subject', raters='repetition no.', ratings=measure, nan_policy='omit')['ICC'].loc[0]
        measures_of_station.append(icc)
    all_measures.append(measures_of_station)
our_icc = pd.DataFrame(all_measures, station_list, measures_list).sort_index()

# %% [markdown]
# ## OUR ICC

# %%
our_icc.round(3)
# Out:
#                    Neck girth  Back neck point to waist  Upper arm girth R  \
# 3DLOOK                  0.998                     0.990              0.990
# 3Davatarbody            0.984                     0.958              0.985
# Expert measurer 1       0.981                     0.908              0.982
# Expert measurer 2       0.983                     0.772              0.980
# Expert measurer 3       0.979                     0.866              0.985
# Expert measurer 4       0.985                     0.913              0.979
# Expert measurer 5       0.980                     0.847              0.994
# MOVE4D                  0.996                     0.965              0.996
# PortalMX                0.988                     0.985              0.988
# SS20                    0.992                     0.967              0.991
# SS@Home                 0.966                     0.955              0.975
# Vitus                   0.994                     0.963              0.977
# eM+                     0.997                     0.995              0.997
#
#                    Back neck point to wrist R  Across back shoulder width  \
# 3DLOOK                                  0.989                       0.987
# 3Davatarbody                            0.963                       0.965
# Expert measurer 1                       0.959                       0.938
# Expert measurer 2                       0.967                       0.919
# Expert measurer 3                       0.954                       0.852
# Expert measurer 4                       0.961                       0.955
# Expert measurer 5                       0.983                       0.945
# MOVE4D                                  0.986                       0.975
# PortalMX                                0.972                       0.894
# SS20                                    0.989                       0.981
# SS@Home                                 0.920                       0.877
# Vitus                                   0.988                       0.922
# eM+                                     0.991                       0.993
#
#                    Bust girth  Waist girth  Hip girth  Thigh girth R  \
# 3DLOOK                  0.989        0.992      0.992          0.985
# 3Davatarbody            0.987        0.996      0.994          0.992
# Expert measurer 1       0.989        0.989      0.988          0.980
# Expert measurer 2       0.991        0.995      0.995          0.983
# Expert measurer 3       0.995        0.997      0.992          0.971
# Expert measurer 4       0.990        0.991      0.992          0.984
# Expert measurer 5       0.990        0.995      0.994          0.988
# MOVE4D                  0.994        0.997      0.999          0.998
# PortalMX                0.995        0.999      0.998          0.992
# SS20                    0.998        0.995      0.995          0.986
# SS@Home                 0.987        0.993      0.993          0.977
# Vitus                   0.997        0.997      0.998          0.997
# eM+                     0.997        0.998      0.996          0.995
#
#                    Total crotch length  Inside leg height
# 3DLOOK                           0.990              0.996
# 3Davatarbody                     0.972              0.987
# Expert measurer 1                0.916              0.945
# Expert measurer 2                0.932              0.985
# Expert measurer 3                0.970              0.984
# Expert measurer 4                0.913              0.977
# Expert measurer 5                0.951              0.983
# MOVE4D                           0.974              0.993
# PortalMX                         0.976              0.989
# SS20                             0.968              0.980
# SS@Home                          0.961              0.968
# Vitus                            0.988              0.992
# eM+                              0.994              0.992

# %% [markdown]
# ## ICC DIFFERENCE

# %%
abs(our_icc - their_icc).round(3)
# Out:
#                    Neck girth  Back neck point to waist  Upper arm girth R  \
# 3DLOOK                  0.000                     0.002              0.004
# 3Davatarbody            0.001                     0.010              0.001
# Expert measurer 1       0.001                     0.003              0.000
# Expert measurer 2       0.000                     0.003              0.000
# Expert measurer 3       0.001                     0.001              0.002
# Expert measurer 4       0.001                     0.001              0.000
# Expert measurer 5       0.000                     0.037              0.000
# MOVE4D                  0.000                     0.007              0.000
# PortalMX                0.000                     0.001              0.001
# SS20                    0.000                     0.001              0.001
# SS@Home                 0.000                     0.023              0.003
# Vitus                   0.000                     0.020              0.001
# eM+                     0.000                     0.000              0.000
#
#                    Back neck point to wrist R  Across back shoulder width  \
# 3DLOOK                                  0.002                       0.002
# 3Davatarbody                            0.009                       0.003
# Expert measurer 1                       0.005                       0.000
# Expert measurer 2                       0.002                       0.000
# Expert measurer 3                       0.002                       0.001
# Expert measurer 4                       0.003                       0.004
# Expert measurer 5                       0.001                       0.009
# MOVE4D                                  0.002                       0.002
# PortalMX                                0.002                       0.001
# SS20                                    0.005                       0.000
# SS@Home                                 0.026                       0.040
# Vitus                                   0.001                       0.002
# eM+                                     0.002                       0.000
#
#                    Bust girth  Waist girth  Hip girth  Thigh girth R  \
# 3DLOOK                  0.001        0.007      0.001          0.001
# 3Davatarbody            0.001        0.000      0.001          0.001
# Expert measurer 1       0.001        0.001      0.000          0.000
# Expert measurer 2       0.001        0.000      0.000          0.001
# Expert measurer 3       0.000        0.000      0.000          0.003
# Expert measurer 4       0.000        0.000      0.000          0.001
# Expert measurer 5       0.000        0.000      0.000          0.002
# MOVE4D                  0.000        0.001      0.000          0.000
# PortalMX                0.000        0.000      0.001          0.001
# SS20                    0.000        0.000      0.001          0.004
# SS@Home                 0.002        0.002      0.002          0.003
# Vitus                   0.000        0.000      0.000          0.000
# eM+                     0.000        0.000      0.000          0.001
#
#                    Total crotch length  Inside leg height
# 3DLOOK                           0.003              0.001
# 3Davatarbody                     0.005              0.003
# Expert measurer 1                0.009              0.003
# Expert measurer 2                0.003              0.001
# Expert measurer 3                0.007              0.001
# Expert measurer 4                0.002              0.002
# Expert measurer 5                0.006              0.005
# MOVE4D                           0.004              0.002
# PortalMX                         0.001              0.002
# SS20                             0.003              0.000
# SS@Home                          0.008              0.002
# Vitus                            0.005              0.001
# eM+                              0.001              0.002

# %% [markdown]
# # CALC SEM

# %%
their_sem = pd.read_csv('data/their_sem.csv', sep=';', header=None)
their_sem.index = ['Expert measurer 1', 'Expert measurer 2', 'Expert measurer 3', 'Expert measurer 4', 'Expert measurer 5', 'SS20', 'Vitus', 'PortalMX', 'MOVE4D', 'SS@Home', '3DLOOK', 'eM+', '3Davatarbody']
their_sem = their_sem.drop(0, axis=1)
their_sem.columns = measures_list
their_sem.sort_index()


all_measures = []
for station in station_list:
    measures_of_station = []
    for measure in measures_list:
        a = treated_data[treated_data['Measuring station'] == station].reset_index()
        icc = pg.intraclass_corr(data=a, targets='Subject', raters='repetition no.', ratings=measure, nan_policy='omit')['ICC'].loc[1]
        sem = a[measure].std() * np.sqrt(1-icc)
        measures_of_station.append(sem)
    all_measures.append(measures_of_station)
our_sem = pd.DataFrame(all_measures, station_list, measures_list).sort_index()

# %% [markdown]
# ## OUR SEM

# %%
our_sem.round(3)
# Out:
#                    Neck girth  Back neck point to waist  Upper arm girth R  \
# 3DLOOK                  1.121                     2.389              3.100
# 3Davatarbody            4.703                     5.320              4.388
# Expert measurer 1       5.351                     9.883              5.502
# Expert measurer 2       5.460                    12.584              6.068
# Expert measurer 3       5.908                    10.168              5.394
# Expert measurer 4       5.357                     9.574              6.350
# Expert measurer 5       4.537                    11.803              3.217
# MOVE4D                  2.303                     5.025              2.504
# PortalMX                3.903                     3.675              4.602
# SS20                    4.614                     7.465              4.549
# SS@Home                 7.477                     9.885              5.546
# Vitus                   3.839                     4.930              5.577
# eM+                     2.247                     2.438              1.887
#
#                    Back neck point to wrist R  Across back shoulder width  \
# 3DLOOK                                  3.561                       3.044
# 3Davatarbody                            8.201                       7.063
# Expert measurer 1                       9.710                       8.138
# Expert measurer 2                       8.270                       9.498
# Expert measurer 3                       9.323                      12.135
# Expert measurer 4                       9.253                       7.533
# Expert measurer 5                       5.787                       7.508
# MOVE4D                                  4.843                       5.874
# PortalMX                                7.310                       8.150
# SS20                                    5.648                       5.457
# SS@Home                                12.637                      11.317
# Vitus                                   5.097                       9.980
# eM+                                     4.496                       2.758
#
#                    Bust girth  Waist girth  Hip girth  Thigh girth R  \
# 3DLOOK                 10.923       10.962      7.849          6.370
# 3Davatarbody           11.621        8.724      7.722          5.340
# Expert measurer 1      11.800       13.497     11.428          8.945
# Expert measurer 2      12.886       10.090      7.620          9.431
# Expert measurer 3       9.691        7.620      9.832         12.063
# Expert measurer 4      13.122       13.363      9.445          8.835
# Expert measurer 5      10.535        8.917      7.451          6.295
# MOVE4D                  7.945        6.807      2.754          2.683
# PortalMX                7.252        4.215      3.658          5.479
# SS20                    6.901       10.500      6.941          8.156
# SS@Home                11.121        9.612      7.958          8.754
# Vitus                   8.227        8.076      4.995          3.458
# eM+                     5.509        5.030      6.887          3.817
#
#                    Total crotch length  Inside leg height
# 3DLOOK                           5.452              2.902
# 3Davatarbody                     8.933              4.935
# Expert measurer 1               21.920             10.747
# Expert measurer 2               19.722              5.953
# Expert measurer 3               12.678              6.014
# Expert measurer 4               19.283              6.888
# Expert measurer 5               14.387              6.128
# MOVE4D                           8.460              3.234
# PortalMX                         7.626              4.434
# SS20                            13.863              6.595
# SS@Home                         17.223              6.884
# Vitus                            8.606              3.952
# eM+                              4.523              4.446

# %% [markdown]
# ## SEM DIFFERENCE

# %%
abs(our_sem - their_sem).round(3)
# Out:
#                    Neck girth  Back neck point to waist  Upper arm girth R  \
# 3DLOOK                  0.079                     0.011              0.800
# 3Davatarbody            0.103                     0.020              0.088
# Expert measurer 1       0.049                     0.117              0.002
# Expert measurer 2       0.160                     0.084              0.068
# Expert measurer 3       0.108                     0.168              0.106
# Expert measurer 4       0.057                     0.174              0.050
# Expert measurer 5       0.063                     1.303              0.083
# MOVE4D                  0.003                     0.025              0.004
# PortalMX                0.003                     0.075              0.098
# SS20                    0.114                     0.265              0.649
# SS@Home                 0.023                     1.415              0.354
# Vitus                   0.161                     1.270              0.023
# eM+                     0.153                     0.062              0.013
#
#                    Back neck point to wrist R  Across back shoulder width  \
# 3DLOOK                                  0.239                       0.456
# 3Davatarbody                            0.201                       0.163
# Expert measurer 1                       0.110                       0.138
# Expert measurer 2                       0.070                       0.098
# Expert measurer 3                       0.077                       0.135
# Expert measurer 4                       0.047                       0.167
# Expert measurer 5                       0.313                       0.392
# MOVE4D                                  0.157                       0.226
# PortalMX                                0.190                       0.550
# SS20                                    0.148                       0.057
# SS@Home                                 1.037                       1.717
# Vitus                                   0.203                       0.180
# eM+                                     0.104                       0.042
#
#                    Bust girth  Waist girth  Hip girth  Thigh girth R  \
# 3DLOOK                  0.323        5.438      0.249          0.630
# 3Davatarbody            0.321        0.124      0.122          0.040
# Expert measurer 1       0.100        0.003      0.172          0.255
# Expert measurer 2       0.186        0.110      0.020          0.031
# Expert measurer 3       0.191        0.380      0.032          0.537
# Expert measurer 4       0.032        0.263      0.255          0.035
# Expert measurer 5       0.235        0.783      0.349          0.195
# MOVE4D                  0.045        0.307      0.054          0.083
# PortalMX                0.048        0.115      0.042          0.021
# SS20                    0.101        0.100      1.059          0.944
# SS@Home                 1.479        1.588      1.342          0.346
# Vitus                   0.027        0.524      0.005          0.242
# eM+                     0.109        0.070      0.087          0.083
#
#                    Total crotch length  Inside leg height
# 3DLOOK                           1.548              0.098
# 3Davatarbody                     0.333              0.135
# Expert measurer 1                0.620              0.613
# Expert measurer 2                0.122              0.147
# Expert measurer 3                0.822              0.014
# Expert measurer 4                0.083              0.212
# Expert measurer 5                1.813              0.228
# MOVE4D                           0.060              0.134
# PortalMX                         0.774              0.166
# SS20                             0.537              0.095
# SS@Home                          1.223              0.716
# Vitus                            1.494              0.248
# eM+                              0.023              0.054

# %% [markdown]
# # CALC PSD

# %%
def calculate_psd(measure, phase):
    data = treated_data[treated_data['Phase'] == phase]
    f1 = data['repetition no.'] == 1
    f2 = data['repetition no.'] == 2
    data = data[ f1 | f2 ][['Subject', 'Measuring station', 'repetition no.', measure]]
    data = data.pivot_table(values=measure, index=['Subject', 'repetition no.'], columns="Measuring station")
    data = data.dropna()

    column_wise = []
    for column1 in data.columns:
        row_wise = []
        for column2 in data.columns:
            if column1 == column2:
                row_wise.append(np.nan)
            else:
                d1 = data[column1]
                d2 = data[column2]
                var = (d1-d2).var()
                sem1 = our_sem[measure].loc[column1]**2
                sem2 = our_sem[measure].loc[column2]**2
                value = np.sqrt(var + (sem1/2) + (sem2/2))
                row_wise.append(value)
        column_wise.append(row_wise)
    data = pd.DataFrame(column_wise, index=data.columns, columns=data.columns)
    data.index.name = None
    return data

# %%
calculate_psd(measure='Neck girth', phase=1).round(1)
# Out:
#                    Expert measurer 1  Expert measurer 2  Expert measurer 3  \
# Expert measurer 1                NaN                9.5               10.7
# Expert measurer 2                9.5                NaN                9.5
# Expert measurer 3               10.7                9.5                NaN
# Expert measurer 4               10.8                9.9               11.0
# SS20                            24.0               23.6               24.2
# Vitus                           22.7               22.2               22.9
#
#                    Expert measurer 4  SS20  Vitus
# Expert measurer 1               10.8  24.0   22.7
# Expert measurer 2                9.9  23.6   22.2
# Expert measurer 3               11.0  24.2   22.9
# Expert measurer 4                NaN  23.0   22.0
# SS20                            23.0   NaN   13.1
# Vitus                           22.0  13.1    NaN

# %%
calculate_psd(measure='Neck girth', phase=2).round(1)
# Out:
#                    3DLOOK  3Davatarbody  Expert measurer 1  Expert measurer 5  \
# 3DLOOK                NaN          25.5               22.1               19.7
# 3Davatarbody         25.5           NaN               16.5               16.7
# Expert measurer 1    22.1          16.5                NaN               10.2
# Expert measurer 5    19.7          16.7               10.2                NaN
# MOVE4D               25.9          15.0               10.5               12.4
# PortalMX             23.7          13.0               11.7               12.8
# SS@Home              29.7          19.4               16.0               17.6
# eM+                  30.1          17.4               16.7               17.9
#
#                    MOVE4D  PortalMX  SS@Home   eM+
# 3DLOOK               25.9      23.7     29.7  30.1
# 3Davatarbody         15.0      13.0     19.4  17.4
# Expert measurer 1    10.5      11.7     16.0  16.7
# Expert measurer 5    12.4      12.8     17.6  17.9
# MOVE4D                NaN       9.2     13.3  14.8
# PortalMX              9.2       NaN     15.3  14.9
# SS@Home              13.3      15.3      NaN  19.7
# eM+                  14.8      14.9     19.7   NaN

# %%
calculate_psd(measure='Upper arm girth R', phase=1).round(1)
# Out:
#                    Expert measurer 1  Expert measurer 2  Expert measurer 3  \
# Expert measurer 1                NaN               12.5               10.7
# Expert measurer 2               12.5                NaN               11.5
# Expert measurer 3               10.7               11.5                NaN
# Expert measurer 4               13.9               13.0               12.4
# SS20                            34.1               33.9               32.4
# Vitus                           17.7               16.5               16.4
#
#                    Expert measurer 4  SS20  Vitus
# Expert measurer 1               13.9  34.1   17.7
# Expert measurer 2               13.0  33.9   16.5
# Expert measurer 3               12.4  32.4   16.4
# Expert measurer 4                NaN  35.3   18.4
# SS20                            35.3   NaN   30.7
# Vitus                           18.4  30.7    NaN

# %%
calculate_psd(measure='Upper arm girth R', phase=2).round(1)
# Out:
#                    3DLOOK  3Davatarbody  Expert measurer 1  Expert measurer 5  \
# 3DLOOK                NaN          15.5               19.2               18.2
# 3Davatarbody         15.5           NaN               16.8               15.5
# Expert measurer 1    19.2          16.8                NaN               11.9
# Expert measurer 5    18.2          15.5               11.9                NaN
# MOVE4D               16.9          14.1                9.4                8.2
# PortalMX             19.1          16.7               11.6                9.4
# SS@Home              16.9          15.7               14.0               15.6
# eM+                  27.5          28.0               29.7               31.4
#
#                    MOVE4D  PortalMX  SS@Home   eM+
# 3DLOOK               16.9      19.1     16.9  27.5
# 3Davatarbody         14.1      16.7     15.7  28.0
# Expert measurer 1     9.4      11.6     14.0  29.7
# Expert measurer 5     8.2       9.4     15.6  31.4
# MOVE4D                NaN       8.1     12.5  29.7
# PortalMX              8.1       NaN     15.0  33.1
# SS@Home              12.5      15.0      NaN  27.3
# eM+                  29.7      33.1     27.3   NaN
