# %%
import pandas as pd

# %%
measures_data = pd.read_csv("data/body_measurements.csv", sep=';', on_bad_lines="warn")

# %%
measures_data.index = measures_data['Subject']

# %%
columns = [
    'Measuring station',
    'repetition no.',
    'Neck girth',
    'Back neck point to waist',
    'Upper arm girth R',
    'Back neck point to wrist R',
    'Across back shoulder width',
    'Bust girth',
    'Waist girth',
    'Hip girth',
    'Thigh girth R',
    'Total crotch length',
    'Inside leg height',
    'Lowaist',
]

# %%
# filter_repetition = measures_data['repetition no.'] == 1
filter_phase = measures_data['Phase'] == 2
station = measures_data['Measuring station'] 
filter_measurer_1 = station == "MOVE4D"
filter_measurer_2 = station == "Expert measurer 1"
filter_measurer_3 = station == "Expert measurer 5"

all_filters = filter_phase & (filter_measurer_1 | filter_measurer_2 | filter_measurer_3)
measures_data = measures_data[all_filters]

# %%
measures_data = measures_data[columns]

# %%
for column in columns:
    if column != 'Measuring station':
        filtered = measures_data[column] > 2000
        measures_data[column].loc[filtered] /= 1000

# %%
measures_data
# Out:
#            Measuring station  repetition no.  Neck girth  \
# Subject
# IEEEP2_01             MOVE4D               1     327.377
# IEEEP2_01             MOVE4D               2     326.233
# IEEEP2_02             MOVE4D               1     382.454
# IEEEP2_02             MOVE4D               2     382.409
# IEEEP2_03             MOVE4D               1     315.109
# ...                      ...             ...         ...
# IEEEP2_72  Expert measurer 5               2     353.000
# IEEEP2_71  Expert measurer 5               1     375.000
# IEEEP2_71  Expert measurer 5               2     360.000
# IEEEP2_71  Expert measurer 1               1     390.000
# IEEEP2_71  Expert measurer 1               2     375.000
#
#            Back neck point to waist  Upper arm girth R  \
# Subject
# IEEEP2_01                   425.868            285.042
# IEEEP2_01                   435.319            288.409
# IEEEP2_02                   419.920            332.674
# ...

# %%
extra_data = pd.read_csv('data/basic_informations.csv', sep=';')
extra_data = extra_data[extra_data['Phase'] == 2]
extra_data.index = extra_data['Subject']
extra_data = extra_data.drop("Subject", axis=1)
extra_data
# Out:
#            Phase     Sex  Age (years)  Weight (kg)  Height (m)  BMI (kg/m^2)  \
# Subject
# IEEEP2_01      2  female           23         64.7       1.640     24.055622
# IEEEP2_02      2    male           32         74.6       1.730     24.925657
# IEEEP2_03      2  female           43         53.7       1.630     20.211525
# IEEEP2_04      2    male           25         90.8       1.790     28.338691
# IEEEP2_05      2    male           42        111.0       1.930     29.799458
# ...          ...     ...          ...          ...         ...           ...
# IEEEP2_68      2  female           55         64.7       1.640     24.055622
# IEEEP2_69      2  female           49         65.4       1.570     26.532517
# IEEEP2_70      2    male           55        122.0       1.920     33.094618
# IEEEP2_71      2  female           55        106.1       1.610     40.932063
# IEEEP2_72      2    male           25         70.7       1.775     22.439992
#
#                    Pantone
# ...

# %%
treated_data = measures_data.join(extra_data)
treated_data = treated_data.drop(["Phase", 'Pantone', 'BMI (kg/m^2)'], axis=1)
treated_data
# Out:
#            Measuring station  repetition no.  Neck girth  \
# Subject
# IEEEP2_01             MOVE4D               1     327.377
# IEEEP2_01             MOVE4D               2     326.233
# IEEEP2_01  Expert measurer 1               1     330.000
# IEEEP2_01  Expert measurer 1               2     335.000
# IEEEP2_01  Expert measurer 5               1     337.000
# ...                      ...             ...         ...
# IEEEP2_72             MOVE4D               2     369.121
# IEEEP2_72  Expert measurer 1               1     355.000
# IEEEP2_72  Expert measurer 1               2     360.000
# IEEEP2_72  Expert measurer 5               1     355.000
# IEEEP2_72  Expert measurer 5               2     353.000
#
#            Back neck point to waist  Upper arm girth R  \
# Subject
# IEEEP2_01                   425.868            285.042
# IEEEP2_01                   435.319            288.409
# IEEEP2_01                   407.500            275.000
# ...

# %%
female_data = treated_data[treated_data['Sex'] == 'female']
female_data.to_pickle('data/female_measures.pkl')

# %%
male_data = treated_data[treated_data['Sex'] == 'male']
male_data.to_pickle('data/male_measures.pkl')

# %%
treated_data.to_pickle('data/all_measures.pkl')
